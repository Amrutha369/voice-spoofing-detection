# %% [markdown]
# <a href="https://colab.research.google.com/github/Amrutha369/voice-spoofing-detection/blob/main/Copy_of_voice_spoofing_detection_using_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikeras
# Out:
# Collecting scikeras
#   Downloading scikeras-0.12.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras) (23.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.3.0)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.12.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow-io
import os
import pandas as pd
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import tensorflow as tf
import tensorflow_io as tfio
import seaborn as sns
import joblib
from IPython.display import Audio
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
# Out:
# Requirement already satisfied: tensorflow-io in /usr/local/lib/python3.10/dist-packages (0.36.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.36.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-io) (0.36.0)

# %%
# Audio params
SAMPLE_RATE = 16000
DURATION = 20.0 # duration in second
AUDIO_LEN = int(SAMPLE_RATE * DURATION)

# Spectrogram params
N_MELS = 128 # freq axis
N_FFT = 2048
SPEC_WIDTH = 256 # time axis
HOP_LEN = 512 # non-overlap region
FMAX = SAMPLE_RATE//2 # max frequency

# CNN params
NUM_CLASSES = 2 # bonafide or spoof
BATCH_SIZE = 32 # adjust based on your memory
EPOCHS = 100 # adjust based on your time
LEARNING_RATE = 0.0001 # adjust based on your model performance
N_ESTIMATORS = 10
RANDOM_STATE = 42

# %%
# Directory and protocol definitions
base_path = '/content/drive/MyDrive/newdataset/LA'
protocol_dir = os.path.join(base_path, 'ASVspoof2019_LA_cm_protocols')
train_dir = os.path.join(base_path, 'ASVspoof2019_LA_train', 'flac')
dev_dir = os.path.join(base_path, 'ASVspoof2019_LA_dev', 'flac')
eval_dir = os.path.join(base_path, 'ASVspoof2019_LA_eval', 'flac')

# %%
# Function to form the full path of a file
def get_file_path(directory, filename):
    return os.path.join(directory, f'{filename}.flac')

# %%
# Function to read the dataset
def read_dataset(protocol_path, directory):
    """Reads the dataset from a protocol file and returns a DataFrame."""
    df = pd.read_csv(protocol_path, sep=' ', header=None, names=['speaker_id', 'filename', 'system_id', 'null', 'class_name'])
    df['filepath'] = df['filename'].apply(lambda x: get_file_path(directory, x))
    df.drop('null', axis=1, inplace=True)
    df.dropna(inplace=True)
    return df

# Function to convert class_name to integer
def label_to_int(class_name):
    if class_name == 'bonafide':
        return 0
    else:
        return 1

# Add target column and subset to DataFrame
def add_columns(df, subset):
    df['target'] = df['class_name'].apply(label_to_int)
    df['subset'] = subset
    return df

# Take samples from each DataFrame by a different number
def sample_data(df, n_bonafide, n_spoof):
    bonafide = df[df['class_name'] == 'bonafide'].head(n_bonafide)
    spoof = df[df['class_name'] != 'bonafide'].head(n_spoof)
    return pd.concat([bonafide, spoof])

# %%
# Create DataFrames for each dataset
train_df = read_dataset(os.path.join(protocol_dir, 'ASVspoof2019.LA.cm.train.trn.txt'), train_dir)
dev_df = read_dataset(os.path.join(protocol_dir, 'ASVspoof2019.LA.cm.dev.trl.txt'), dev_dir)
eval_df = read_dataset(os.path.join(protocol_dir, 'ASVspoof2019.LA.cm.eval.trl.txt'), eval_dir)

# Add columns to each DataFrame
train_df = add_columns(train_df, 'train')
dev_df = add_columns(dev_df, 'dev')
eval_df = add_columns(eval_df, 'eval')

# Take samples from each DataFrame by a different number
train_df = sample_data(train_df, 70, 70)
dev_df = sample_data(dev_df, 30, 30)
eval_df = sample_data(eval_df, 30, 30)

# %%
#Combine three dataframes into one dataframe
data_df = pd.concat([train_df, dev_df, eval_df], ignore_index=True)

# %%
data_df.head(len(data_df))
# Out:
#     speaker_id      filename system_id class_name  \
# 0      LA_0089  LA_T_1000406         -   bonafide
# 1      LA_0088  LA_T_1007571         -   bonafide
# 2      LA_0090  LA_T_1007663         -   bonafide
# 3      LA_0084  LA_T_1011221         -   bonafide
# 4      LA_0086  LA_T_1013597         -   bonafide
# ..         ...           ...       ...        ...
# 195    LA_0007  LA_E_1001964         -      spoof
# 196    LA_0043  LA_E_1001976         -      spoof
# 197    LA_0014  LA_E_1002073         -      spoof
# 198    LA_0033  LA_E_1002282         -      spoof
# 199    LA_0041  LA_E_1002394         -      spoof
#
#                                               filepath  target subset
# 0    /content/drive/MyDrive/newdataset/LA/ASVspoof2...       0  train
# 1    /content/drive/MyDrive/newdataset/LA/ASVspoof2...       0  train
# 2    /content/drive/MyDrive/newdataset/LA/ASVspoof2...       0  train
# 3    /content/drive/MyDrive/newdataset/LA/ASVspoof2...       0  train
# 4    /content/drive/MyDrive/newdataset/LA/ASVspoof2...       0  train
# ..                                                 ...     ...    ...
# 195  /content/drive/MyDrive/newdataset/LA/ASVspoof2...       1   eval
# 196  /content/drive/MyDrive/newdataset/LA/ASVspoof2...       1   eval
# 197  /content/drive/MyDrive/newdataset/LA/ASVspoof2...       1   eval
# 198  /content/drive/MyDrive/newdataset/LA/ASVspoof2...       1   eval
# 199  /content/drive/MyDrive/newdataset/LA/ASVspoof2...       1   eval
#
# [200 rows x 7 columns]

# %%
import librosa

def audio_to_spectrogram(filepath):
    # Load audio file using librosa
    audio, sample_rate = librosa.load(filepath)

    # Normalize the audio
    audio_norm = (audio - np.min(audio)) / (np.max(audio) - np.min(audio))

    # Compute the spectrogram using librosa
    spectrogram = librosa.feature.melspectrogram(y=audio_norm, sr=sample_rate)

    # Convert the spectrogram to decibels
    spectrogram_db = librosa.power_to_db(spectrogram, ref=np.max)

    # Add channel dimension
    spectrogram_db = np.expand_dims(spectrogram_db, axis=-1)

    # Resize spectrogram to the specified size
    image = tf.image.resize(spectrogram_db, [SPEC_WIDTH, N_MELS])

    return image

# Adding the spectrogram column to the DataFrame
data_df['spectrogram'] = data_df['filepath'].apply(audio_to_spectrogram)

# %%
# Selecting a spectrogram from the DataFrame
first_spectrogram = data_df.loc[5, 'spectrogram']

# Using the imshow function to display the spectrogram
plt.figure(figsize=(10, 4))
plt.imshow(tf.squeeze(first_spectrogram), aspect='auto', origin='lower')
plt.title('Spectrogram')
plt.ylabel('Frequency bin')
plt.xlabel('Time frame')
plt.colorbar(format='%+2.0f dB')
plt.tight_layout()
plt.show()
print("The size of the spectrogram is:", first_spectrogram.shape)
# Out:
# The size of the spectrogram is: (256, 128, 1)

# %%
# Splitting the data based on the 'subset' column
train_data = data_df[data_df['subset'] == 'train']
dev_data = data_df[data_df['subset'] == 'dev']
eval_data = data_df[data_df['subset'] == 'eval']

# Converting the list of spectrograms into NumPy arrays
X_train = np.stack(train_data['spectrogram'].to_list())
X_dev = np.stack(dev_data['spectrogram'].to_list())
X_eval = np.stack(eval_data['spectrogram'].to_list())

# Converting target into NumPy arrays
y_train = train_data['target'].to_numpy()
y_dev = dev_data['target'].to_numpy()
y_eval = eval_data['target'].to_numpy()

# %%
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_dev shape: {X_dev.shape}")
print(f"y_dev shape: {y_dev.shape}")
print(f"X_eval shape: {X_eval.shape}")
print(f"y_eval shape: {y_eval.shape}")
# Out:
# X_train shape: (140, 256, 128, 1)
# y_train shape: (140,)
# X_dev shape: (30, 256, 128, 1)
# y_dev shape: (30,)
# X_eval shape: (30, 256, 128, 1)
# y_eval shape: (30,)

# %%
from tensorflow.keras.optimizers import Adam

def create_cnn_model(input_shape):
    model = Sequential()
    # 1st conv layer
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(BatchNormalization())

    # 2nd conv layer
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
    model.add(BatchNormalization())

    # 3rd conv layer
    model.add(Conv2D(32, (2, 2), activation='relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(BatchNormalization())

    # 4th conv layer
    model.add(Conv2D(64, (2, 2), activation='relu'))
    model.add(MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
    model.add(BatchNormalization())

    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))

    # Additional dense layer
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))

    # Compile the model with Adam optimizer
    optimizer = Adam(learning_rate=LEARNING_RATE)
    model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model

# Create the CNN model with Adam optimizer
cnn_model = create_cnn_model((X_train.shape[1], X_train.shape[2], 1))

# %%
# Display the summary of the CNN model
cnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 254, 126, 32)      320
#
#  max_pooling2d_8 (MaxPoolin  (None, 127, 63, 32)       0
#  g2D)
#
#  batch_normalization_8 (Bat  (None, 127, 63, 32)       128
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 125, 61, 32)       9248
#
#  max_pooling2d_9 (MaxPoolin  (None, 63, 31, 32)        0
#  g2D)
#
#  batch_normalization_9 (Bat  (None, 63, 31, 32)        128
#  chNormalization)
#
#  conv2d_10 (Conv2D)          (None, 62, 30, 32)        4128
#
#  max_pooling2d_10 (MaxPooli  (None, 31, 15, 32)        0
#  ng2D)
#
#  batch_normalization_10 (Ba  (None, 31, 15, 32)        128
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 30, 14, 64)        8256
#
#  max_pooling2d_11 (MaxPooli  (None, 15, 7, 64)         0
#  ng2D)
#
#  batch_normalization_11 (Ba  (None, 15, 7, 64)         256
#  tchNormalization)
#
#  flatten_2 (Flatten)         (None, 6720)              0
#
#  dense_6 (Dense)             (None, 64)                430144
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 454849 (1.74 MB)
# Trainable params: 454529 (1.73 MB)
# Non-trainable params: 320 (1.25 KB)
# _________________________________________________________________

# %%
# Train the CNN model
cnn_model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 5s 22ms/step - loss: 0.7441 - accuracy: 0.5643
# Epoch 2/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.5847 - accuracy: 0.6643
# Epoch 3/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4795 - accuracy: 0.7857
# Epoch 4/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4691 - accuracy: 0.8000
# Epoch 5/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.4094 - accuracy: 0.8500
# Epoch 6/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3522 - accuracy: 0.8429
# Epoch 7/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.3191 - accuracy: 0.8714
# Epoch 8/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.3269 - accuracy: 0.8786
# Epoch 9/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2292 - accuracy: 0.9143
# Epoch 10/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.2563 - accuracy: 0.9071
# Epoch 11/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2287 - accuracy: 0.9357
# Epoch 12/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1716 - accuracy: 0.9500
# Epoch 13/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2062 - accuracy: 0.9286
# Epoch 14/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1776 - accuracy: 0.9643
# Epoch 15/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2072 - accuracy: 0.9000
# Epoch 16/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1786 - accuracy: 0.9286
# Epoch 17/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.1395 - accuracy: 0.9786
# Epoch 18/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1356 - accuracy: 0.9571
# Epoch 19/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1558 - accuracy: 0.9643
# Epoch 20/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1466 - accuracy: 0.9571
# Epoch 21/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1447 - accuracy: 0.9500
# Epoch 22/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1069 - accuracy: 0.9857
# Epoch 23/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1357 - accuracy: 0.9643
# Epoch 24/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1079 - accuracy: 0.9857
# Epoch 25/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0700 - accuracy: 0.9929
# Epoch 26/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1199 - accuracy: 0.9714
# Epoch 27/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0907 - accuracy: 0.9857
# Epoch 28/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0676 - accuracy: 0.9857
# Epoch 29/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.1075 - accuracy: 0.9571
# Epoch 30/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0692 - accuracy: 0.9857
# Epoch 31/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0594 - accuracy: 0.9929
# Epoch 32/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0715 - accuracy: 0.9857
# Epoch 33/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0662 - accuracy: 0.9857
# Epoch 34/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0485 - accuracy: 0.9857
# Epoch 36/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0495 - accuracy: 0.9857
# Epoch 37/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0391 - accuracy: 0.9929
# Epoch 38/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0508 - accuracy: 0.9929
# Epoch 39/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0486 - accuracy: 0.9929
# Epoch 41/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0586 - accuracy: 0.9786
# Epoch 42/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0462 - accuracy: 0.9929
# Epoch 43/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0745 - accuracy: 0.9786
# Epoch 44/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0592 - accuracy: 0.9786
# Epoch 45/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0482 - accuracy: 0.9857
# Epoch 46/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0475 - accuracy: 0.9786
# Epoch 47/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0475 - accuracy: 0.9929
# Epoch 48/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0368 - accuracy: 0.9929
# Epoch 50/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0393 - accuracy: 0.9929
# Epoch 52/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0400 - accuracy: 0.9929
# Epoch 55/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0258 - accuracy: 0.9929
# Epoch 56/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0364 - accuracy: 0.9929
# Epoch 62/100
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0325 - accuracy: 0.9929
# Epoch 63/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0305 - accuracy: 0.9857
# Epoch 68/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0276 - accuracy: 0.9929
# Epoch 71/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0197 - accuracy: 0.9929
# Epoch 76/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0235 - accuracy: 0.9929
# Epoch 78/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0252 - accuracy: 0.9929
# Epoch 79/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0208 - accuracy: 0.9929
# Epoch 80/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0254 - accuracy: 0.9929
# Epoch 81/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0162 - accuracy: 0.9929
# Epoch 83/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0260 - accuracy: 1.0000

# %%
# Save the model
cnn_model.save('/content/drive/MyDrive/save/voice-spoofing-detection-using-cnn.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Compute accuracy on training data
train_accuracy = cnn_model.evaluate(X_train, y_train)[1]
print(f"Accuracy on training data: {train_accuracy * 100:.2f}%")

# Compute accuracy on validation data
val_accuracy = cnn_model.evaluate(X_dev, y_dev)[1]
print(f'Accuracy on validation data: {val_accuracy * 100:.2f}%')

# Compute accuracy on test data
test_accuracy = cnn_model.evaluate(X_eval, y_eval)[1]
print(f'Accuracy on test data: {test_accuracy * 100:.2f}%')
# Out:
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0010 - accuracy: 1.0000
# Accuracy on training data: 100.00%
# 1/1 [==============================] - 0s 35ms/step - loss: 0.7333 - accuracy: 0.8333
# Accuracy on validation data: 83.33%
# 1/1 [==============================] - 0s 35ms/step - loss: 0.5226 - accuracy: 0.8333
# Accuracy on test data: 83.33%

# %%
import os

# Define the paths to the bonafide and spoof audio files
bonafide_file_path = "/content/drive/MyDrive/newdataset/LA/ASVspoof2019_LA_eval/flac/LA_E_1023303.flac"
spoof_file_path = "/content/drive/MyDrive/newdataset/LA/ASVspoof2019_LA_eval/flac/LA_E_1000147.flac"

print("Bonafide file:", bonafide_file_path)
print("Spoof file:", spoof_file_path)

# Creating spectrograms for both files
bonafide_spectrogram = audio_to_spectrogram(bonafide_file_path)
spoof_spectrogram = audio_to_spectrogram(spoof_file_path)
X_new = np.stack([bonafide_spectrogram, spoof_spectrogram])

# Performing prediction
y_pred = cnn_model.predict(X_new)


# Convert probabilities to classes
y_pred_classes = [1 if pred > 0.5 else 0 for pred in y_pred]

# Create a dictionary for mapping
class_dict = {0: 'bonafide', 1: 'spoof'}

# Apply mapping to predictions
y_pred_labels = [class_dict[pred] for pred in y_pred_classes]
print("Predicted classes:", y_pred_labels)

# Print the results
for i, pred in enumerate(y_pred_labels):
    print(f"File {i+1} is {pred}")
# Out:
# Bonafide file: /content/drive/MyDrive/newdataset/LA/ASVspoof2019_LA_eval/flac/LA_E_1023303.flac
# Spoof file: /content/drive/MyDrive/newdataset/LA/ASVspoof2019_LA_eval/flac/LA_E_1000147.flac
# 1/1 [==============================] - 0s 250ms/step
# Predicted classes: ['bonafide', 'spoof']
# File 1 is bonafide
# File 2 is spoof

# %%
from sklearn.metrics import classification_report

# Assuming you have X_eval and y_eval datasets for testing

# Perform predictions on the evaluation set
y_eval_pred = cnn_model.predict(X_eval)

# Convert predictions to binary labels (0 or 1)
y_eval_pred_binary = (y_eval_pred > 0.5).astype(int)

# Calculate classification report
report = classification_report(y_eval, y_eval_pred_binary, target_names=class_dict.values())

# Print report
print(report)
# Out:
# 1/1 [==============================] - 0s 23ms/step
#               precision    recall  f1-score   support
#
#     bonafide       0.86      0.80      0.83        15
#        spoof       0.81      0.87      0.84        15
#
#     accuracy                           0.83        30
#    macro avg       0.83      0.83      0.83        30
# weighted avg       0.83      0.83      0.83        30

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have X_eval and y_eval datasets for testing

# Perform predictions on the evaluation set
y_eval_pred = cnn_model.predict(X_eval)

# Convert predictions to binary labels (0 or 1)
y_eval_pred_binary = (y_eval_pred > 0.5).astype(int)

# Calculate confusion matrix
cm = confusion_matrix(y_eval, y_eval_pred_binary)

# Create a heatmap plot
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=class_dict.values(), yticklabels=class_dict.values())
plt.title('Confusion Matrix')
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')

# Show the plot
plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step
